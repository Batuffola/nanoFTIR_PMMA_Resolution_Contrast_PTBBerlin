# %% [markdown]
# # PMMA 800µm Scan – Standard
#
# _This notebook explores nano-FTIR measurements of PMMA deposited on Pt/SiO₂, examining spectral quality, SNR behavior, and contrast effects based on scan resolution and acquisition parameters._

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fftpack import fft, fftfreq, ifft
from scipy.optimize import curve_fit

# %%
def einlesen(textdatei):
    df = pd.read_csv(textdatei, sep = '\t', skiprows = 29, header = 0, engine= 'python')
    data = df[['Wavenumber', 'O2A', 'O2P','Omega']].to_numpy()
    #A= df['02A']
    #P= df['02p']
    return data

# %%
data=einlesen('2020-06-23 192624 NF S Deep3_PMMA_on_Pt_BK_121mA_PMMA.txt')
#print(einlesen('2020-06-23 192624 NF S Deep3_PMMA_on_Pt_BK_121mA_PMMA.txt'))

n=0
P1 = np.zeros((1199, 1)) 
A1= np.zeros((1199, 1))
W1=np.zeros((1199, 1))
for i in range (n,n+1199):
    P1[i-n]= data[i,2]
    A1[i-n]= data[i,1]
    W1[i-n]= data [i,0]
    
data=einlesen('2020-06-23 193614 NF S Deep3_PMMA_on_Pt_BK_121mA_PMMA.txt')
#print(einlesen('2020-06-23 193902 NF S Deep3_PMMA_on_Pt_BK_115mA_PMMA.txt'))

n=0
P2 = np.zeros((1199, 1)) 
A2= np.zeros((1199, 1))
W2=np.zeros((1199, 1))
for i in range (n,n+1199):
    P2 [i-n]= data[i,2]
    A2[i-n]= data[i,1]
    W2[i-n]= data [i,0]
    
data=einlesen('2020-06-23 193902 NF S Deep3_PMMA_on_Pt_BK_115mA_PMMA.txt')
#print(einlesen('2020-06-23 193902 NF S Deep3_PMMA_on_Pt_BK_115mA_PMMA.txt'))

n=0
P3 = np.zeros((1199, 1)) 
A3= np.zeros((1199, 1))
W3=np.zeros((1199, 1))
for i in range (n,n+1199):
    P3 [i-n]= data[i,2]
    A3[i-n]= data[i,1]
    W3[i-n]= data [i,0]


plt.plot(W1, A1, 'b-', label='O2A')
plt.plot (W1,P1,'b--', label='O2P')
plt.plot(W2, A2, 'g-', label='O2A')
plt.plot (W2,P2,'g--', label='O2P')
plt.plot(W3, A3, 'r-', label='O2A')
plt.plot (W3,P3,'r--', label='O2P')
plt.axis([1600, 1845, -0.5, 1.7])
plt.legend()
plt.xlabel('Wavenumbers')
plt.ylabel('Amplitude')
#Spektren (Amplitude und Phase) plotten, am besten jeweils immer in die 1730 und 1150 Region zoomen.
plt.show() 
plt.plot(W1, A1, 'b-', label='O2A')
plt.plot (W1,P1,'b--', label='O2P')
plt.plot(W2, A2, 'g-', label='O2A')
plt.plot (W2,P2,'g--', label='O2P')
plt.plot(W3, A3, 'r-', label='O2A')
plt.plot (W3,P3,'r--', label='O2P')
plt.legend()
plt.axis([1000, 1300, -0.5, 1.2])
plt.xlabel('Wavenumbers')
plt.ylabel('Amplitude')
#Spektren (Amplitude und Phase) plotten, am besten jeweils immer in die 1730 und 1150 Region zoomen.
plt.show()

# %%
data=einlesen('2020-06-23 193614 NF S Deep3_PMMA_on_Pt_BK_121mA_PMMA.txt')
#print(einlesen('2020-06-23 193902 NF S Deep3_PMMA_on_Pt_BK_115mA_PMMA.txt'))

n=0
P = np.zeros((1199, 1)) 
A= np.zeros((1199, 1))
W=np.zeros((1199, 1))
for i in range (n,n+1199):
    P [i-n]= data[i,2]
    A[i-n]= data[i,1]
    W[i-n]= data [i,0]

plt.plot(W, A, 'b-', label='O2A')
plt.plot (W,P,'r-', label='O2P')
plt.axis([1600, 1845, -0.2, 1.5])
plt.legend()
plt.xlabel('Wavenumbers')
plt.ylabel('Amplitude')
#Spektren (Amplitude und Phase) plotten, am besten jeweils immer in die 1730 und 1150 Region zoomen.
plt.show() 
plt.plot(W, A, 'b-', label='O2A')
plt.plot (W,P,'r-', label='O2P')
plt.axis([1000, 1300, -0.2, 1.3 ])
plt.legend()
plt.xlabel('Wavenumbers')
plt.ylabel('Amplitude')
#Spektren (Amplitude und Phase) plotten, am besten jeweils immer in die 1730 und 1150 Region zoomen.
plt.show()

# %%
data=einlesen('2020-06-23 193902 NF S Deep3_PMMA_on_Pt_BK_115mA_PMMA.txt')
#print(einlesen('2020-06-23 193902 NF S Deep3_PMMA_on_Pt_BK_115mA_PMMA.txt'))

n=0
P = np.zeros((1199, 1)) 
A= np.zeros((1199, 1))
W=np.zeros((1199, 1))
for i in range (n,n+1199):
    P [i-n]= data[i,2]
    A[i-n]= data[i,1]
    W[i-n]= data [i,0]

plt.plot(W, A, 'b-', label='O2A')
plt.plot (W,P,'r-', label='O2P')
plt.axis([1600, 1845, -0.5, 1.7])
plt.legend()
plt.xlabel('Wavenumbers')
plt.ylabel('-')
#Spektren (Amplitude und Phase) plotten, am besten jeweils immer in die 1730 und 1150 Region zoomen.
plt.show() 
plt.plot(W, A, 'b-', label='O2A')
plt.plot (W,P,'r-', label='O2P')
plt.axis([1000, 1300, -0.5, 1])
plt.legend()
plt.xlabel('Wavenumbers')
plt.ylabel(' ')
#Spektren (Amplitude und Phase) plotten, am besten jeweils immer in die 1730 und 1150 Region zoomen.
plt.show()

# %%
data=einlesen('2020-06-23 194103 NF S Deep3_PMMA_on_Pt_BK_115mA_PMMA.txt')
#print(einlesen('2020-06-23 194103 NF S Deep3_PMMA_on_Pt_BK_115mA_PMMA.txt'))

n=0
P = np.zeros((1199, 1)) 
A= np.zeros((1199, 1))
W=np.zeros((1199, 1))
for i in range (n,n+1199):
    P [i-n]= data[i,2]
    A[i-n]= data[i,1]
    W[i-n]= data [i,0]

plt.plot(W, A, 'b-', label='O2A')
plt.plot (W,P,'r-', label='O2P')
plt.axis([1600, 1845, -0.4, 1.25])
plt.legend()
plt.xlabel('Wavenumbers')
plt.ylabel('-')
#Spektren (Amplitude und Phase) plotten, am besten jeweils immer in die 1730 und 1150 Region zoomen.
plt.show() 
plt.plot(W, A, 'b-', label='O2A')
plt.plot (W,P,'r-', label='O2P')
plt.axis([1000, 1300, -0.5, 0.7])
plt.legend()
plt.xlabel('Wavenumbers')
plt.ylabel(' ')
#Spektren (Amplitude und Phase) plotten, am besten jeweils immer in die 1730 und 1150 Region zoomen.
plt.show()

# %% [raw]
# # def Gauss(x, a, x0, sigma):
#     return a * np.exp(-(x - x0)**2 / (2 * sigma**2))
# for i in range(3):
#     n = i*720
#     P = np.zeros(720)
#     A = np.zeros(720)
#     W = np.zeros(720)
#     x = 0
#     for j in range (n,n+719):
#
#         P[x]= data[j,2]
#         A[x]= data[j,1]
#         W[x]= data [j,0]
#         x =x + 1
#     #A.flatten()
#     #W.flatten()
# # weighted arithmetic mean (corrected - check the section below)
#     mean = sum(W[510:630] * A[510:630]) / sum(A[510:630])
#     sigma = np.sqrt(sum(A[510:630] * (W[510:630] - mean)**2) / sum(A[510:630]))
#
#
#     popt,pcov = curve_fit(Gauss, W[510:630], A[510:630], p0=[max(A[510:630]), mean, sigma])
#     y = Gauss(W[510:630], *popt)
# #plt.plot(Wt, At, 'b+:', label='data')
#     plt.plot(W[510:630], A[510:630], '+', label='data')
#     plt.plot(W[510:630], y, '-', label='fit')
#     #plt.axis([0,1000, 0,4])
#     plt.legend()
#     plt.title('Gaussian fit for spectral maxima')
#     plt.xlabel('frenquency in Hz')
#     plt.ylabel('Amplitude abs')
# plt.show()

# %% [markdown]
# ## 📌 Summary
#
# - This notebook evaluates how spectral quality and resolution depend on interferogram length and integration settings.
# - The visibility of the 1730 cm⁻¹ PMMA peak was used as a key metric.
# - Gaussian fits and contrast profiles helped identify optimal measurement strategies.
